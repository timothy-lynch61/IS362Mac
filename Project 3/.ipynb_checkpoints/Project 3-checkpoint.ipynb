# %% [markdown]
# # Project 3
# Student: Tim Lynch<br>
# Professor: Charles Pak
#
# Your assignment involves combining information from a number of SQL tables, then displaying the information in a pandas DataFrame.
#
# Your task is to create a pandas DataFrame tht displays Customer's Last Name and First Name, and each customer's purchased Track names and Album Titles. The information should be sorted by Customer Last Name then Customer FirstName

# %%
import pandas as pd
import sqlalchemy

engine = sqlalchemy.create_engine('mysql+pymysql://root:@localhost:3306/chinook')

# %%
df = pd.read_sql_table('customer', engine)
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     341         """
# --> 342         return _ConnectionFairy._checkout(self)
#     343
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     787         if not fairy:
# --> 788             fairy = _ConnectionRecord.checkout(pool)
#     789
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     528     def checkout(cls, pool):
# --> 529         rec = pool._do_get()
# ...

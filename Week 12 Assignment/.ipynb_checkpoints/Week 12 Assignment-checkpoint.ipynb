# %% [markdown]
# # Week 12 Assignment
#
# Student: Tim Lynch<br>
# Professor: Charles Pak<br>
#
# For this week we are to pull information from the New York Times using their API's. I chose to work with the Books, API. I am not that strong in Jason so was only able to get it to as far as results before hitting a road block.

# %%
import pandas as pd
import json

# %%
data = pd.read_json("https://api.nytimes.com/svc/books/v3/lists/current/hardcover-fiction.json?api-key=4jkJjryTRsis4EGxZj3o6Mbps8ssJZcc")

# %%
#Convert to DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#                            status  \
# bestsellers_date               OK
# books                          OK
# corrections                    OK
# display_name                   OK
# list_name                      OK
# list_name_encoded              OK
# next_published_date            OK
# normal_list_ends_at            OK
# previous_published_date        OK
# published_date                 OK
# published_date_description     OK
# updated                        OK
#
#                                                                     copyright  \
# bestsellers_date            Copyright (c) 2019 The New York Times Company....
# books                       Copyright (c) 2019 The New York Times Company....
# corrections                 Copyright (c) 2019 The New York Times Company....
# display_name                Copyright (c) 2019 The New York Times Company....
# list_name                   Copyright (c) 2019 The New York Times Company....
# ...
